# %% [markdown]
# # 更新opencv到最新版

# %%
# !apt update -y
# !apt install libgl1-mesa-glx -y
# !pip install opencv-contrib-python -U

# %% [markdown]
# # 顯示影像
# * 注意：opencv使用bgr，顯示出來顏色會不正常

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

print(cv2.__version__)
img = cv2.imread('family.jpg')

plt.imshow(img)

# %% [markdown]
# # 用rgb顯示影像，使用numpy slicing的方式

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

print(cv2.__version__)
img = cv2.imread('family.jpg')

plt.imshow(img[:,:,::-1])

# %% [markdown]
# # 顯示影像的資訊，如形狀，佔的位元組

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

print(cv2.__version__)
img = cv2.imread('family.jpg')

print(img.shape)
print(img.size)
# Out:
# 4.4.0
# (565, 849, 3)
# 1439055

# %% [markdown]
# # 顯示影像真正的矩陣值
# * 注意，opencv使用channel last的方式
# * 如果shape = (a, b, 3)，表示有a個(bx3)的圖片
# * 有些程式是channel first，(3, a, b)因此表示成3個(axb)的圖片

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

print(cv2.__version__)
img = cv2.imread('family.jpg')

print(img.shape)
print(img)
# Out:
# 4.4.0
# (565, 849, 3)
# [[[  5  95  52]
#   [ 11 104  59]
#   [ 17 116  68]
#   ...
#   [ 30  84  55]
#   [ 38  95  64]
#   [ 49 102  69]]
#
#  [[  6  96  53]
#   [ 17 110  65]
#   [ 22 121  73]
#   ...
#   [ 34  86  56]
#   [ 59 113  78]
#   [ 72 122  88]]
#
#  [[ 12 101  57]
#   [ 22 114  67]
#   [ 27 124  74]
#   ...
#   [ 46  97  63]
#   [ 73 122  84]
#   [100 141 104]]
#
#  ...
#
#  [[208 255 247]
#   [205 255 247]
#   [199 255 242]
#   ...
#   [ 45 162  93]
#   [ 33 154  80]
#   [ 24 146  70]]
#
#  [[205 254 246]
#   [204 255 246]
#   [202 254 244]
#   ...
#   [ 28 146  75]
#   [ 34 153  78]
#   [ 26 146  68]]
#
#  [[197 253 242]
#   [198 254 243]
#   [202 254 244]
#   ...
#   [ 36 154  79]
#   [ 35 154  76]
#   [ 26 144  69]]]

# %% [markdown]
# # 用numpy方式表示圖片，值介於0-1之間

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

print(cv2.__version__)
img = cv2.imread('family.jpg')

img = img / 255
print(img)
plt.imshow(img[:,:,::-1])
# Out:
# 4.4.0
# [[[0.01960784 0.37254902 0.20392157]
#   [0.04313725 0.40784314 0.23137255]
#   [0.06666667 0.45490196 0.26666667]
#   ...
#   [0.11764706 0.32941176 0.21568627]
#   [0.14901961 0.37254902 0.25098039]
#   [0.19215686 0.4        0.27058824]]
#
#  [[0.02352941 0.37647059 0.20784314]
#   [0.06666667 0.43137255 0.25490196]
#   [0.08627451 0.4745098  0.28627451]
#   ...
#   [0.13333333 0.3372549  0.21960784]
#   [0.23137255 0.44313725 0.30588235]
#   [0.28235294 0.47843137 0.34509804]]
#
#  [[0.04705882 0.39607843 0.22352941]
#   [0.08627451 0.44705882 0.2627451 ]
#   [0.10588235 0.48627451 0.29019608]
#   ...
#   [0.18039216 0.38039216 0.24705882]
#   [0.28627451 0.47843137 0.32941176]
#   [0.39215686 0.55294118 0.40784314]]
#
#  ...
#
#  [[0.81568627 1.         0.96862745]
#   [0.80392157 1.         0.96862745]
#   [0.78039216 1.         0.94901961]
#   ...
#   [0.17647059 0.63529412 0.36470588]
#   [0.12941176 0.60392157 0.31372549]
#   [0.09411765 0.57254902 0.2745098 ]]
#
#  [[0.80392157 0.99607843 0.96470588]
#   [0.8        1.         0.96470588]
#   [0.79215686 0.99607843 0.95686275]
#   ...
#   [0.10980392 0.57254902 0.29411765]
#   [0.13333333 0.6        0.30588235]
#   [0.10196078 0.57254902 0.26666667]]
#
#  [[0.77254902 0.99215686 0.94901961]
#   [0.77647059 0.99607843 0.95294118]
#   [0.79215686 0.99607843 0.95686275]
#   ...
#   [0.14117647 0.60392157 0.30980392]
#   [0.1372549  0.60392157 0.29803922]
#   [0.10196078 0.56470588 0.27058824]]]

# %% [markdown]
# # 隨機產生灰階圖

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img=np.random.randint(0,256,size=[256,256],dtype=np.uint8)

print(img.shape)
display(img)
plt.imshow(img)

# %% [markdown]
# # 隨機產生彩色圖，並且將三個通道取出來

# %%
import cv2
import numpy as np
img=np.random.randint(0,256,size=[256,256,3],dtype=np.uint8)

print(img.shape)
display(img[:,:,0])
display(img[:,:,1])
display(img[:,:,2])
plt.imshow(img[:,:,::-1])
# Out:
# (256, 256, 3)
# array([[235, 121,   8, ...,  71, 100, 228],
#        [251, 173, 119, ...,  61,  15, 192],
#        [155, 200, 202, ..., 148, 140, 122],
#        ...,
#        [168, 252,  13, ..., 115,  67,  53],
#        [197,  73,  30, ..., 210, 171, 100],
#        [  8, 134, 162, ..., 244, 252, 222]], dtype=uint8)
# array([[243,  74, 242, ...,  25, 251, 226],
#        [ 23, 204,  11, ..., 102,  11,  90],
#        [ 35, 251, 104, ..., 221,  82,  45],
#        ...,
#        [ 58, 238, 122, ...,   3, 195, 162],
#        [111,  58,  25, ..., 182, 153, 178],
#        [ 34, 240,  35, ...,  33, 220,  23]], dtype=uint8)
# array([[101, 228, 121, ..., 239,  10, 141],
#        [ 41,  42, 170, ...,  34, 228,  20],
#        [109, 222,  97, ..., 167, 207,  58],
#        ...,
#        [123, 141, 106, ..., 171, 132, 202],
#        [ 34, 187, 222, ...,  80, 123,  89],
#        [ 80, 129,  58, ..., 128,   0,  99]], dtype=uint8)

# %% [markdown]
# # 有興趣區域(ROI)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('family.jpg')

part = img[200:400, 250:450]
plt.imshow(part[:,:,::-1])

# %% [markdown]
# # 臉部當作ROI

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

a=cv2.imread("lenacolor.png",cv2.IMREAD_UNCHANGED)

face=np.random.randint(0,256,(180,100,3))
a[220:400,250:350]=face
plt.imshow(a[:,:,::-1])

# %% [markdown]
# # 複製ROI

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

lena=cv2.imread("lena512.bmp",cv2.IMREAD_UNCHANGED)
dollar=cv2.imread("dollar.bmp",cv2.IMREAD_UNCHANGED)

face=lena[220:400,250:350]
dollar[160:340,200:300]=face

plt.imshow(dollar)

# %% [markdown]
# # 將不同的通道取出

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

lena=cv2.imread("lenacolor.png",cv2.IMREAD_UNCHANGED)
plt.imshow(lena[:,:,0])

# %%
plt.imshow(lena[:,:,1])

# %%
plt.imshow(lena[:,:,2])

# %%
b, g, r = cv2.split(lena)
plt.imshow(b)

# %% [markdown]
# # 重新組合不同channels

# %%
newimage = cv2.merge((r,g,b))
plt.imshow(newimage)

# %% [markdown]
# # 將紅色值全部變成0，只留gb

# %%
r.fill(0)
newimage = cv2.merge((r,g,b))
plt.imshow(newimage)

# %% [markdown]
# # 製作邊界

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

BLUE = [255,0,0]

img1 = cv2.imread('opencv_logo.png')
img1 = img1[:,:,::-1]

replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

fig, ax = plt.subplots(figsize = (15, 5))

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
# Out:
# (<AxesSubplot:title={'center':'CONSTANT'}>,
#  <matplotlib.image.AxesImage at 0x7fdb21001860>,
#  Text(0.5, 1.0, 'CONSTANT'))
