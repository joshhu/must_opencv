# %% [markdown]
# # 載入套件

# %%
# !pip install opencv-contrib-python -U

# %%
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import cv2
import numpy as np
print(cv2.__version__)
# Out:
# 4.1.2

# %% [markdown]
# # Sobel運算元

# %%
o = cv2.imread('sobel4.bmp',cv2.IMREAD_GRAYSCALE)
Sobelx = cv2.Sobel(o,-1,1,0) 
cv2_imshow(o)
cv2_imshow(Sobelx)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64D52B00>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC73C8>

# %% [markdown]
# # Sobel x的應用

# %%
o = cv2.imread('sobel4.bmp',cv2.IMREAD_GRAYSCALE)
Sobelx = cv2.Sobel(o,cv2.CV_64F,1,0)
Sobelx = cv2.convertScaleAbs(Sobelx)    
cv2_imshow(o)
cv2_imshow(Sobelx)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC7C50>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC7D68>

# %% [markdown]
# # Sobel Y的應用

# %%
o = cv2.imread('sobel4.bmp',cv2.IMREAD_GRAYSCALE)
Sobely = cv2.Sobel(o,cv2.CV_64F,0,1)
Sobely = cv2.convertScaleAbs(Sobely)
cv2_imshow(o)
cv2_imshow(Sobely)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC7D30>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC7E10>

# %% [markdown]
# # Sobel X, Y找出線條

# %%
o = cv2.imread('sobel4.bmp',cv2.IMREAD_GRAYSCALE)
Sobelx = cv2.Sobel(o,cv2.CV_64F,1,0)
Sobely = cv2.Sobel(o,cv2.CV_64F,0,1)
Sobelx = cv2.convertScaleAbs(Sobelx)    
Sobely = cv2.convertScaleAbs(Sobely)  
Sobelxy =  cv2.addWeighted(Sobelx,0.5,Sobely,0.5,0)  
cv2_imshow(o)
cv2_imshow(Sobelxy)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6A5C0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6A588>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6A550>

# %%
o = cv2.imread('lena.bmp',cv2.IMREAD_GRAYSCALE)
Sobelx = cv2.Sobel(o,cv2.CV_64F,1,0)
Sobely = cv2.Sobel(o,cv2.CV_64F,0,1)
Sobelx = cv2.convertScaleAbs(Sobelx)    
Sobely = cv2.convertScaleAbs(Sobely)  
Sobelxy =  cv2.addWeighted(Sobelx,0.5,Sobely,0.5,0)  
Sobelxy11=cv2.Sobel(o,cv2.CV_64F,1,1)
Sobelxy11=cv2.convertScaleAbs(Sobelxy11) 
cv2_imshow(o)
cv2_imshow(Sobelxy)
cv2_imshow(Sobelxy11)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64CD9470>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64CD9668>

# %% [markdown]
# # Scharr運算元

# %%
o = cv2.imread('scharr.bmp',cv2.IMREAD_GRAYSCALE)
Scharrx = cv2.Scharr(o,cv2.CV_64F,1,0)
Scharrx = cv2.convertScaleAbs(Scharrx)    
cv2_imshow(o)
cv2_imshow(Scharrx)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CD94A8>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CC7FD0>

# %% [markdown]
# # 圖形的Scharr Y

# %%
o = cv2.imread('scharr.bmp',cv2.IMREAD_GRAYSCALE)
Scharry = cv2.Scharr(o,cv2.CV_64F,0,1)
Scharry = cv2.convertScaleAbs(Scharry) 
   
cv2_imshow(o)
cv2_imshow(Scharry)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CD94A8>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64CD90B8>

# %% [markdown]
# # 圖形的Scharr X, Y

# %%
o = cv2.imread('sobel4.bmp',cv2.IMREAD_GRAYSCALE)
scharrx = cv2.Scharr(o,cv2.CV_64F,1,0)
scharry = cv2.Scharr(o,cv2.CV_64F,0,1)
scharrx = cv2.convertScaleAbs(scharrx)    
scharry = cv2.convertScaleAbs(scharry)  
scharrxy =  cv2.addWeighted(scharrx,0.5,scharry,0.5,0)  

cv2_imshow(o)
cv2_imshow(scharrxy)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64C6A358>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF64C6A390>

# %% [markdown]
# # Shcarr Lena

# %%
o = cv2.imread('lena.bmp',cv2.IMREAD_GRAYSCALE)
Sobelx = cv2.Sobel(o,cv2.CV_64F,1,0,ksize=3)
Sobely = cv2.Sobel(o,cv2.CV_64F,0,1,ksize=3)
Sobelx = cv2.convertScaleAbs(Sobelx)    
Sobely = cv2.convertScaleAbs(Sobely)  
Sobelxy =  cv2.addWeighted(Sobelx,0.5,Sobely,0.5,0) 
Scharrx = cv2.Scharr(o,cv2.CV_64F,1,0)
Scharry = cv2.Scharr(o,cv2.CV_64F,0,1)
Scharrx = cv2.convertScaleAbs(Scharrx)    
Scharry = cv2.convertScaleAbs(Scharry)  
Scharrxy =  cv2.addWeighted(Scharrx,0.5,Scharry,0.5,0) 
cv2_imshow(o)
cv2_imshow(Sobelxy)
cv2_imshow(Scharrxy)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6AE80>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6AE10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF64C6AF28>

# %% [markdown]
# # Laplacian

# %%
o = cv2.imread('laplacian.bmp',cv2.IMREAD_GRAYSCALE)
Laplacian = cv2.Laplacian(o,cv2.CV_64F)
Laplacian = cv2.convertScaleAbs(Laplacian)   
cv2_imshow(o)
cv2_imshow(Laplacian)
# Out:
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF6E549860>
# <PIL.Image.Image image mode=L size=636x474 at 0x7FEF6E549320>

# %% [markdown]
# # Laplacian Lena

# %%
o = cv2.imread('lena.bmp',cv2.IMREAD_GRAYSCALE)
Laplacian = cv2.Laplacian(o,cv2.CV_64F)
Laplacian = cv2.convertScaleAbs(Laplacian)   
cv2_imshow(o)
cv2_imshow(Laplacian)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6E549860>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6E549C50>
